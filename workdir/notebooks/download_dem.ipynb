# %%
import os
import sys

os.chdir('/work')
print(os.getcwd())
# Out:
# /work

# %%
# !python -m isce.applications.dem --help
# Out:
# usage: dem.py [-h] [-a ACTION] [-c] [-m META] [-s SOURCE] [-f]
#               [-v FILLINGVALUE] [-b BBOX [BBOX ...]] [-p PAIRS [PAIRS ...]]
#               [-k] [-r] [-l] [-d DIR] [-o OUTPUT] [-n UNAME] [-w PASSWORD]
#               [-t TYPE] [-x] [-u URL]
#
# options:
#   -h, --help            show this help message and exit
#   -a ACTION, --action ACTION
#                         Possible actions: stitch or download (default:
#                         stitch).
#   -c, --correct         Apply correction EGM96 -> WGS84 (default: False). The
#                         output metadata is in xml format only
#   -m META, --meta META  What type of metadata file is created. Possible
#                         values: xml or rsc (default: xml)
#   -s SOURCE, --source SOURCE
#                         Dem SRTM source. Possible values 1 or 3 (default: 1)
#   -f, --filling         Flag to instruct to fill missing Dems with null values
# ...

# %%
# !python -m isce.applications.dem  -a stitch -b -7 -5 105 108 -k  -r -l  -s 1 -d /mnt/data_storage/dem
# Out:
# Could not create a stitched DEM. Some tiles are missing
# S06E105.SRTMGL1.hgt.zip = failed
# S06E106.SRTMGL1.hgt.zip = failed
# S06E107.SRTMGL1.hgt.zip = failed
# S07E105.SRTMGL1.hgt.zip = failed
# S07E106.SRTMGL1.hgt.zip = failed
# S07E107.SRTMGL1.hgt.zip = failed

# %% [markdown]
# Could not create a stitched DEM. Some tiles are missing
#
# S06E105.SRTMGL1.hgt.zip = failed
#
# S06E106.SRTMGL1.hgt.zip = failed
#
# S06E107.SRTMGL1.hgt.zip = failed
#
# S07E105.SRTMGL1.hgt.zip = failed
#
# S07E106.SRTMGL1.hgt.zip = failed
#
# S07E107.SRTMGL1.hgt.zip = failed
#
#
# のようなエラーが出る場合はコペルニクスの認証が失敗しているからです。
